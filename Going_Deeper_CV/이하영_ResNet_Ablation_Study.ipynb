# %% [markdown]
# 1. ResNet-34, ResNet-50 모델 구현이 정상적으로 진행되었는가?
#     - 블록함수 구현이 제대로 진행되었으며 구현한 모델의 summary가 예상된 형태로 출력되었다.
# 2. 구현한 ResNet 모델을 활용하여 Image Classification 모델 훈련이 가능한가?
#     - tensorflow-datasets에서 제공하는 cats_vs_dogs 데이터셋으로 학습 진행 시 loss가 감소하는 것이 확인되었다.
# 3. Ablation Study 결과가 바른 포맷으로 제출되었는가?
#     - ResNet-34, ResNet-50 각각 plain모델과 residual모델을 동일한 epoch만큼 학습시켰을 때의 validation accuracy 기준으로 Ablation Study 결과표가 작성되었다.

# %%
import tensorflow as tf

# %%
# ResNet의 첫 conv 블록을 생성하는 함수
def conv2_resnet_block(x, is_50, is_plain):

    def conv_block(x, is_50):
        if is_50:
            x = tf.keras.layers.Conv2D(64, (1,1), strides=1, padding='same')(x)
            x = tf.keras.layers.BatchNormalization()(x)
            x = tf.keras.layers.Activation('relu')(x)
            x = tf.keras.layers.Conv2D(64, (3,3), strides=1, padding='same')(x)
            x = tf.keras.layers.BatchNormalization()(x)
            x = tf.keras.layers.Activation('relu')(x)
            x = tf.keras.layers.Conv2D(256, (1,1), strides=1, padding='same')(x)
            x = tf.keras.layers.BatchNormalization()(x)
        else:
            x = tf.keras.layers.Conv2D(64, (3,3), strides=1, padding='same')(x)
            x = tf.keras.layers.BatchNormalization()(x)
            x = tf.keras.layers.Activation('relu')(x)
            x = tf.keras.layers.Conv2D(64, (3,3), strides=1, padding='same')(x)
            x = tf.keras.layers.BatchNormalization()(x)

        return x

    if is_50:
        if is_plain:
            for _ in range(3):
                x = conv_block(x, is_50=True)
                x = tf.keras.layers.Activation('relu')(x)
        else:
            for _ in range(3):
                shortcut = tf.keras.layers.Conv2D(256, (1,1), strides=1, padding='same')(x)
                x = conv_block(x, is_50=True)
                x = tf.keras.layers.Add()([x, shortcut])
                x = tf.keras.layers.Activation('relu')(x)
    else:
        if is_plain:
            for _ in range(3):
                x = conv_block(x, is_50=False)
                x = tf.keras.layers.Activation('relu')(x)
        else:
            for _ in range(3):
                shortcut = tf.keras.layers.Conv2D(64, (1,1), strides=1, padding='same')(x)
                x = conv_block(x, is_50=False)
                x = tf.keras.layers.Add()([x, shortcut])
                x = tf.keras.layers.Activation('relu')(x)
                
    return x

# %%
# 전체 ResNet 블록을 생성하는 함수
def build_resnet_block(input_layer, num_cnn, channel, is_50=False, is_plain=False):
    
    x = input_layer

    if is_50:
        if is_plain:
            x = conv2_resnet_block(x, is_50=True, is_plain=True)
            for cnn in range(num_cnn):
                if cnn == 0:
                    x = tf.keras.layers.Conv2D(channel, (1,1), strides=2, padding='same')(x)
                else:
                    x = tf.keras.layers.Conv2D(channel, (1,1), strides=1, padding='same')(x)
                x = tf.keras.layers.BatchNormalization()(x)
                x = tf.keras.layers.Activation('relu')(x)
                x = tf.keras.layers.Conv2D(channel, (3,3), strides=1, padding='same')(x)
                x = tf.keras.layers.BatchNormalization()(x)
                x = tf.keras.layers.Activation('relu')(x)
                x = tf.keras.layers.Conv2D(channel*4, (1,1), strides=1, padding='same')(x)
                x = tf.keras.layers.BatchNormalization()(x)
                x = tf.keras.layers.Activation('relu')(x)
        else:
            x = conv2_resnet_block(x, is_50=True, is_plain=False)
            for cnn in range(num_cnn):
                if cnn == 0:
                    shortcut = tf.keras.layers.Conv2D(channel*4, (1,1), strides=2, padding='same')(x)
                    x = tf.keras.layers.Conv2D(channel, (1,1), strides=2, padding='same')(x)
                else:
                    shortcut = tf.keras.layers.Conv2D(channel*4, (1,1), strides=1, padding='same')(x)
                    x = tf.keras.layers.Conv2D(channel, (1,1), strides=1, padding='same')(x)
                x = tf.keras.layers.BatchNormalization()(x)
                x = tf.keras.layers.Activation('relu')(x)
                x = tf.keras.layers.Conv2D(channel, (3,3), strides=1, padding='same')(x)
                x = tf.keras.layers.BatchNormalization()(x)
                x = tf.keras.layers.Activation('relu')(x)
                x = tf.keras.layers.Conv2D(channel*4, (1,1), strides=1, padding='same')(x)
                x = tf.keras.layers.BatchNormalization()(x)
                x = tf.keras.layers.Add()([x, shortcut])
                x = tf.keras.layers.Activation('relu')(x)
    else:
        if is_plain:
            x = conv2_resnet_block(x, is_50=False, is_plain=True)
            for cnn in range(num_cnn):
                if cnn == 0:
                    x = tf.keras.layers.Conv2D(channel, (3,3), strides=2, padding='same')(x)
                else:
                    x = tf.keras.layers.Conv2D(channel, (3,3), strides=1, padding='same')(x)
                x = tf.keras.layers.BatchNormalization()(x)
                x = tf.keras.layers.Activation('relu')(x)
                x = tf.keras.layers.Conv2D(channel, (3,3), strides=1, padding='same')(x)
                x = tf.keras.layers.BatchNormalization()(x)
                x = tf.keras.layers.Activation('relu')(x)
        else:
            x = conv2_resnet_block(x, is_50=False, is_plain=False)
            for cnn in range(num_cnn):
                if cnn == 0:
                    shortcut = tf.keras.layers.Conv2D(channel, (1,1), strides=2, padding='same')(x)
                    x = tf.keras.layers.Conv2D(channel, (3,3), strides=2, padding='same')(x)
                else:
                    shortcut = x
                    x = tf.keras.layers.Conv2D(channel, (3,3), strides=1, padding='same')(x)
                x = tf.keras.layers.BatchNormalization()(x)
                x = tf.keras.layers.Activation('relu')(x)
                x = tf.keras.layers.Conv2D(channel, (3,3), strides=1, padding='same')(x)
                x = tf.keras.layers.BatchNormalization()(x)
                x = tf.keras.layers.Activation('relu')(x)
                x = tf.keras.layers.Add()([x, shortcut])
                x = tf.keras.layers.Activation('relu')(x)

    return x

# %%
# ResNet을 생성하는 함수
def build_resnet(input_shape, is_50=False, is_plain=False):
    
    num_cnns = [3, 4, 6, 3]
    channels = [64, 128, 256, 512]

    input_layer = tf.keras.layers.Input(shape=input_shape, dtype='float32')

    x = input_layer
    x = tf.keras.layers.Conv2D(64, (7,7), strides=2, padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.MaxPooling2D((3,3), strides=2, padding='same')(x)

    for _, (num_cnn, channel) in enumerate(zip(num_cnns[1:], channels[1:])):
        x = build_resnet_block(
            input_layer=x,
            num_cnn=num_cnn,
            channel=channel,
            is_50=is_50,
            is_plain=is_plain,
        )
    
    x = tf.keras.layers.AveragePooling2D((2,2), padding='same')(x)
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(1000, activation='softmax', kernel_initializer='he_normal')(x)

    model = tf.keras.Model(
        inputs=input_layer,
        outputs=x
    )
    
    return model

# %%
# ResNet-34을 만들고 요약
resnet_34 = build_resnet(input_shape=(100, 100, 3), is_50=False, is_plain=False)
resnet_34.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 50, 50, 64)   9472        ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 50, 50, 64)  256         ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 50, 50, 64)   0           ['batch_normalization[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 25, 25, 64)   0           ['activation[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 25, 25, 64)   36928       ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 25, 25, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 25, 25, 64)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 25, 25, 64)   36928       ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 25, 25, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  conv2d_1 (Conv2D)              (None, 25, 25, 64)   4160        ['max_pooling2d[0][0]']
#
#  add (Add)                      (None, 25, 25, 64)   0           ['batch_normalization_2[0][0]',
#                                                                   'conv2d_1[0][0]']
#
#  activation_2 (Activation)      (None, 25, 25, 64)   0           ['add[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 25, 25, 64)   36928       ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 25, 25, 64)  256         ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 25, 25, 64)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 25, 25, 64)   36928       ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 25, 25, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  conv2d_4 (Conv2D)              (None, 25, 25, 64)   4160        ['activation_2[0][0]']
#
#  add_1 (Add)                    (None, 25, 25, 64)   0           ['batch_normalization_4[0][0]',
#                                                                   'conv2d_4[0][0]']
#
#  activation_4 (Activation)      (None, 25, 25, 64)   0           ['add_1[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 25, 25, 64)   36928       ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 25, 25, 64)  256         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 25, 25, 64)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 25, 25, 64)   36928       ['activation_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 25, 25, 64)  256         ['conv2d_9[0][0]']
#  rmalization)
#
#  conv2d_7 (Conv2D)              (None, 25, 25, 64)   4160        ['activation_4[0][0]']
#
#  add_2 (Add)                    (None, 25, 25, 64)   0           ['batch_normalization_6[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  activation_6 (Activation)      (None, 25, 25, 64)   0           ['add_2[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 13, 13, 128)  73856       ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 13, 13, 128)  512        ['conv2d_11[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 13, 13, 128)  0           ['batch_normalization_7[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 13, 13, 128)  147584      ['activation_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 13, 13, 128)  512        ['conv2d_12[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 13, 13, 128)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 13, 13, 128)  8320        ['activation_6[0][0]']
#
#  add_3 (Add)                    (None, 13, 13, 128)  0           ['activation_8[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  activation_9 (Activation)      (None, 13, 13, 128)  0           ['add_3[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 13, 13, 128)  147584      ['activation_9[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 13, 13, 128)  512        ['conv2d_13[0][0]']
#  rmalization)
#
#  activation_10 (Activation)     (None, 13, 13, 128)  0           ['batch_normalization_9[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 13, 13, 128)  147584      ['activation_10[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 13, 13, 128)  512        ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 13, 13, 128)  0           ['batch_normalization_10[0][0]']
#
#  add_4 (Add)                    (None, 13, 13, 128)  0           ['activation_11[0][0]',
#                                                                   'activation_9[0][0]']
#
#  activation_12 (Activation)     (None, 13, 13, 128)  0           ['add_4[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 13, 13, 128)  147584      ['activation_12[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 13, 13, 128)  512        ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 13, 13, 128)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 13, 13, 128)  147584      ['activation_13[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 13, 13, 128)  512        ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 13, 13, 128)  0           ['batch_normalization_12[0][0]']
#
#  add_5 (Add)                    (None, 13, 13, 128)  0           ['activation_14[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_15 (Activation)     (None, 13, 13, 128)  0           ['add_5[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 13, 13, 128)  147584      ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 13, 13, 128)  512        ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 13, 13, 128)  0           ['batch_normalization_13[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 13, 13, 128)  147584      ['activation_16[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 13, 13, 128)  512        ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 13, 13, 128)  0           ['batch_normalization_14[0][0]']
#
#  add_6 (Add)                    (None, 13, 13, 128)  0           ['activation_17[0][0]',
#                                                                   'activation_15[0][0]']
#
#  activation_18 (Activation)     (None, 13, 13, 128)  0           ['add_6[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 13, 13, 64)   73792       ['activation_18[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 13, 13, 64)  256         ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 13, 13, 64)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 13, 13, 64)   36928       ['activation_19[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 13, 13, 64)  256         ['conv2d_21[0][0]']
#  ormalization)
#
#  conv2d_19 (Conv2D)             (None, 13, 13, 64)   8256        ['activation_18[0][0]']
#
#  add_7 (Add)                    (None, 13, 13, 64)   0           ['batch_normalization_16[0][0]',
#                                                                   'conv2d_19[0][0]']
#
#  activation_20 (Activation)     (None, 13, 13, 64)   0           ['add_7[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 13, 13, 64)   36928       ['activation_20[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 13, 13, 64)  256         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 13, 13, 64)   0           ['batch_normalization_17[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 13, 13, 64)   36928       ['activation_21[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 13, 13, 64)  256         ['conv2d_24[0][0]']
#  ormalization)
#
#  conv2d_22 (Conv2D)             (None, 13, 13, 64)   4160        ['activation_20[0][0]']
#
#  add_8 (Add)                    (None, 13, 13, 64)   0           ['batch_normalization_18[0][0]',
#                                                                   'conv2d_22[0][0]']
#
#  activation_22 (Activation)     (None, 13, 13, 64)   0           ['add_8[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 13, 13, 64)   36928       ['activation_22[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 13, 13, 64)  256         ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 13, 13, 64)   0           ['batch_normalization_19[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 13, 13, 64)   36928       ['activation_23[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 13, 13, 64)  256         ['conv2d_27[0][0]']
#  ormalization)
#
#  conv2d_25 (Conv2D)             (None, 13, 13, 64)   4160        ['activation_22[0][0]']
#
#  add_9 (Add)                    (None, 13, 13, 64)   0           ['batch_normalization_20[0][0]',
#                                                                   'conv2d_25[0][0]']
#
#  activation_24 (Activation)     (None, 13, 13, 64)   0           ['add_9[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 7, 7, 256)    147712      ['activation_24[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_21[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 7, 7, 256)    590080      ['activation_25[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_22[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 7, 7, 256)    16640       ['activation_24[0][0]']
#
#  add_10 (Add)                   (None, 7, 7, 256)    0           ['activation_26[0][0]',
#                                                                   'conv2d_28[0][0]']
#
#  activation_27 (Activation)     (None, 7, 7, 256)    0           ['add_10[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 7, 7, 256)    590080      ['activation_27[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_23[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 7, 7, 256)    590080      ['activation_28[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_24[0][0]']
#
#  add_11 (Add)                   (None, 7, 7, 256)    0           ['activation_29[0][0]',
#                                                                   'activation_27[0][0]']
#
#  activation_30 (Activation)     (None, 7, 7, 256)    0           ['add_11[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 7, 7, 256)    590080      ['activation_30[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_25[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 7, 7, 256)    590080      ['activation_31[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_26[0][0]']
#
#  add_12 (Add)                   (None, 7, 7, 256)    0           ['activation_32[0][0]',
#                                                                   'activation_30[0][0]']
#
#  activation_33 (Activation)     (None, 7, 7, 256)    0           ['add_12[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 7, 7, 256)    590080      ['activation_33[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_27[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 7, 7, 256)    590080      ['activation_34[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_28[0][0]']
#
#  add_13 (Add)                   (None, 7, 7, 256)    0           ['activation_35[0][0]',
#                                                                   'activation_33[0][0]']
#
#  activation_36 (Activation)     (None, 7, 7, 256)    0           ['add_13[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 7, 7, 256)    590080      ['activation_36[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_29[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 7, 7, 256)    590080      ['activation_37[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_30[0][0]']
#
#  add_14 (Add)                   (None, 7, 7, 256)    0           ['activation_38[0][0]',
#                                                                   'activation_36[0][0]']
#
#  activation_39 (Activation)     (None, 7, 7, 256)    0           ['add_14[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 7, 7, 256)    590080      ['activation_39[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_31[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 7, 7, 256)    590080      ['activation_40[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_32[0][0]']
#
#  add_15 (Add)                   (None, 7, 7, 256)    0           ['activation_41[0][0]',
#                                                                   'activation_39[0][0]']
#
#  activation_42 (Activation)     (None, 7, 7, 256)    0           ['add_15[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 7, 7, 64)     147520      ['activation_42[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 7, 7, 64)    256         ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 7, 7, 64)     0           ['batch_normalization_33[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 7, 7, 64)     36928       ['activation_43[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 7, 7, 64)    256         ['conv2d_43[0][0]']
#  ormalization)
#
#  conv2d_41 (Conv2D)             (None, 7, 7, 64)     16448       ['activation_42[0][0]']
#
#  add_16 (Add)                   (None, 7, 7, 64)     0           ['batch_normalization_34[0][0]',
#                                                                   'conv2d_41[0][0]']
#
#  activation_44 (Activation)     (None, 7, 7, 64)     0           ['add_16[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 7, 7, 64)     36928       ['activation_44[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 7, 7, 64)    256         ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 7, 7, 64)     0           ['batch_normalization_35[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 7, 7, 64)     36928       ['activation_45[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 7, 7, 64)    256         ['conv2d_46[0][0]']
#  ormalization)
#
#  conv2d_44 (Conv2D)             (None, 7, 7, 64)     4160        ['activation_44[0][0]']
#
#  add_17 (Add)                   (None, 7, 7, 64)     0           ['batch_normalization_36[0][0]',
#                                                                   'conv2d_44[0][0]']
#
#  activation_46 (Activation)     (None, 7, 7, 64)     0           ['add_17[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 7, 7, 64)     36928       ['activation_46[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 7, 7, 64)    256         ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 7, 7, 64)     0           ['batch_normalization_37[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 7, 7, 64)     36928       ['activation_47[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 7, 7, 64)    256         ['conv2d_49[0][0]']
#  ormalization)
#
#  conv2d_47 (Conv2D)             (None, 7, 7, 64)     4160        ['activation_46[0][0]']
#
#  add_18 (Add)                   (None, 7, 7, 64)     0           ['batch_normalization_38[0][0]',
#                                                                   'conv2d_47[0][0]']
#
#  activation_48 (Activation)     (None, 7, 7, 64)     0           ['add_18[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 4, 4, 512)    295424      ['activation_48[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 4, 4, 512)    0           ['batch_normalization_39[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 4, 4, 512)    2359808     ['activation_49[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_52[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 4, 4, 512)    0           ['batch_normalization_40[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 4, 4, 512)    33280       ['activation_48[0][0]']
#
#  add_19 (Add)                   (None, 4, 4, 512)    0           ['activation_50[0][0]',
#                                                                   'conv2d_50[0][0]']
#
#  activation_51 (Activation)     (None, 4, 4, 512)    0           ['add_19[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 4, 4, 512)    2359808     ['activation_51[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 4, 4, 512)    0           ['batch_normalization_41[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 4, 4, 512)    2359808     ['activation_52[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_53 (Activation)     (None, 4, 4, 512)    0           ['batch_normalization_42[0][0]']
#
#  add_20 (Add)                   (None, 4, 4, 512)    0           ['activation_53[0][0]',
#                                                                   'activation_51[0][0]']
#
#  activation_54 (Activation)     (None, 4, 4, 512)    0           ['add_20[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 4, 4, 512)    2359808     ['activation_54[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 4, 4, 512)    0           ['batch_normalization_43[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 4, 4, 512)    2359808     ['activation_55[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_56 (Activation)     (None, 4, 4, 512)    0           ['batch_normalization_44[0][0]']
#
#  add_21 (Add)                   (None, 4, 4, 512)    0           ['activation_56[0][0]',
#                                                                   'activation_54[0][0]']
#
#  activation_57 (Activation)     (None, 4, 4, 512)    0           ['add_21[0][0]']
#
#  average_pooling2d (AveragePool  (None, 2, 2, 512)   0           ['activation_57[0][0]']
#  ing2D)
#
#  flatten (Flatten)              (None, 2048)         0           ['average_pooling2d[0][0]']
#
#  dense (Dense)                  (None, 1000)         2049000     ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 22,856,232
# Trainable params: 22,839,464
# Non-trainable params: 16,768
# __________________________________________________________________________________________________

# %%
# ResNet-50을 만들고 요약
resnet_50 = build_resnet(input_shape=(100, 100, 3), is_50=True, is_plain=False)
resnet_50.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  conv2d_325 (Conv2D)            (None, 50, 50, 64)   9472        ['input_6[0][0]']
#
#  batch_normalization_291 (Batch  (None, 50, 50, 64)  256         ['conv2d_325[0][0]']
#  Normalization)
#
#  activation_304 (Activation)    (None, 50, 50, 64)   0           ['batch_normalization_291[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 25, 25, 64)  0           ['activation_304[0][0]']
#
#  conv2d_327 (Conv2D)            (None, 25, 25, 64)   4160        ['max_pooling2d_5[0][0]']
#
#  batch_normalization_292 (Batch  (None, 25, 25, 64)  256         ['conv2d_327[0][0]']
#  Normalization)
#
#  activation_305 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_292[0][0]']
#
#  conv2d_328 (Conv2D)            (None, 25, 25, 64)   36928       ['activation_305[0][0]']
#
#  batch_normalization_293 (Batch  (None, 25, 25, 64)  256         ['conv2d_328[0][0]']
#  Normalization)
#
#  activation_306 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_293[0][0]']
#
#  conv2d_329 (Conv2D)            (None, 25, 25, 256)  16640       ['activation_306[0][0]']
#
#  batch_normalization_294 (Batch  (None, 25, 25, 256)  1024       ['conv2d_329[0][0]']
#  Normalization)
#
#  conv2d_326 (Conv2D)            (None, 25, 25, 256)  16640       ['max_pooling2d_5[0][0]']
#
#  add_44 (Add)                   (None, 25, 25, 256)  0           ['batch_normalization_294[0][0]',
#                                                                   'conv2d_326[0][0]']
#
#  activation_307 (Activation)    (None, 25, 25, 256)  0           ['add_44[0][0]']
#
#  conv2d_331 (Conv2D)            (None, 25, 25, 64)   16448       ['activation_307[0][0]']
#
#  batch_normalization_295 (Batch  (None, 25, 25, 64)  256         ['conv2d_331[0][0]']
#  Normalization)
#
#  activation_308 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_295[0][0]']
#
#  conv2d_332 (Conv2D)            (None, 25, 25, 64)   36928       ['activation_308[0][0]']
#
#  batch_normalization_296 (Batch  (None, 25, 25, 64)  256         ['conv2d_332[0][0]']
#  Normalization)
#
#  activation_309 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_296[0][0]']
#
#  conv2d_333 (Conv2D)            (None, 25, 25, 256)  16640       ['activation_309[0][0]']
#
#  batch_normalization_297 (Batch  (None, 25, 25, 256)  1024       ['conv2d_333[0][0]']
#  Normalization)
#
#  conv2d_330 (Conv2D)            (None, 25, 25, 256)  65792       ['activation_307[0][0]']
#
#  add_45 (Add)                   (None, 25, 25, 256)  0           ['batch_normalization_297[0][0]',
#                                                                   'conv2d_330[0][0]']
#
#  activation_310 (Activation)    (None, 25, 25, 256)  0           ['add_45[0][0]']
#
#  conv2d_335 (Conv2D)            (None, 25, 25, 64)   16448       ['activation_310[0][0]']
#
#  batch_normalization_298 (Batch  (None, 25, 25, 64)  256         ['conv2d_335[0][0]']
#  Normalization)
#
#  activation_311 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_298[0][0]']
#
#  conv2d_336 (Conv2D)            (None, 25, 25, 64)   36928       ['activation_311[0][0]']
#
#  batch_normalization_299 (Batch  (None, 25, 25, 64)  256         ['conv2d_336[0][0]']
#  Normalization)
#
#  activation_312 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_299[0][0]']
#
#  conv2d_337 (Conv2D)            (None, 25, 25, 256)  16640       ['activation_312[0][0]']
#
#  batch_normalization_300 (Batch  (None, 25, 25, 256)  1024       ['conv2d_337[0][0]']
#  Normalization)
#
#  conv2d_334 (Conv2D)            (None, 25, 25, 256)  65792       ['activation_310[0][0]']
#
#  add_46 (Add)                   (None, 25, 25, 256)  0           ['batch_normalization_300[0][0]',
#                                                                   'conv2d_334[0][0]']
#
#  activation_313 (Activation)    (None, 25, 25, 256)  0           ['add_46[0][0]']
#
#  conv2d_339 (Conv2D)            (None, 13, 13, 128)  32896       ['activation_313[0][0]']
#
#  batch_normalization_301 (Batch  (None, 13, 13, 128)  512        ['conv2d_339[0][0]']
#  Normalization)
#
#  activation_314 (Activation)    (None, 13, 13, 128)  0           ['batch_normalization_301[0][0]']
#
#  conv2d_340 (Conv2D)            (None, 13, 13, 128)  147584      ['activation_314[0][0]']
#
#  batch_normalization_302 (Batch  (None, 13, 13, 128)  512        ['conv2d_340[0][0]']
#  Normalization)
#
#  activation_315 (Activation)    (None, 13, 13, 128)  0           ['batch_normalization_302[0][0]']
#
#  conv2d_341 (Conv2D)            (None, 13, 13, 512)  66048       ['activation_315[0][0]']
#
#  batch_normalization_303 (Batch  (None, 13, 13, 512)  2048       ['conv2d_341[0][0]']
#  Normalization)
#
#  conv2d_338 (Conv2D)            (None, 13, 13, 512)  131584      ['activation_313[0][0]']
#
#  add_47 (Add)                   (None, 13, 13, 512)  0           ['batch_normalization_303[0][0]',
#                                                                   'conv2d_338[0][0]']
#
#  activation_316 (Activation)    (None, 13, 13, 512)  0           ['add_47[0][0]']
#
#  conv2d_343 (Conv2D)            (None, 13, 13, 128)  65664       ['activation_316[0][0]']
#
#  batch_normalization_304 (Batch  (None, 13, 13, 128)  512        ['conv2d_343[0][0]']
#  Normalization)
#
#  activation_317 (Activation)    (None, 13, 13, 128)  0           ['batch_normalization_304[0][0]']
#
#  conv2d_344 (Conv2D)            (None, 13, 13, 128)  147584      ['activation_317[0][0]']
#
#  batch_normalization_305 (Batch  (None, 13, 13, 128)  512        ['conv2d_344[0][0]']
#  Normalization)
#
#  activation_318 (Activation)    (None, 13, 13, 128)  0           ['batch_normalization_305[0][0]']
#
#  conv2d_345 (Conv2D)            (None, 13, 13, 512)  66048       ['activation_318[0][0]']
#
#  batch_normalization_306 (Batch  (None, 13, 13, 512)  2048       ['conv2d_345[0][0]']
#  Normalization)
#
#  conv2d_342 (Conv2D)            (None, 13, 13, 512)  262656      ['activation_316[0][0]']
#
#  add_48 (Add)                   (None, 13, 13, 512)  0           ['batch_normalization_306[0][0]',
#                                                                   'conv2d_342[0][0]']
#
#  activation_319 (Activation)    (None, 13, 13, 512)  0           ['add_48[0][0]']
#
#  conv2d_347 (Conv2D)            (None, 13, 13, 128)  65664       ['activation_319[0][0]']
#
#  batch_normalization_307 (Batch  (None, 13, 13, 128)  512        ['conv2d_347[0][0]']
#  Normalization)
#
#  activation_320 (Activation)    (None, 13, 13, 128)  0           ['batch_normalization_307[0][0]']
#
#  conv2d_348 (Conv2D)            (None, 13, 13, 128)  147584      ['activation_320[0][0]']
#
#  batch_normalization_308 (Batch  (None, 13, 13, 128)  512        ['conv2d_348[0][0]']
#  Normalization)
#
#  activation_321 (Activation)    (None, 13, 13, 128)  0           ['batch_normalization_308[0][0]']
#
#  conv2d_349 (Conv2D)            (None, 13, 13, 512)  66048       ['activation_321[0][0]']
#
#  batch_normalization_309 (Batch  (None, 13, 13, 512)  2048       ['conv2d_349[0][0]']
#  Normalization)
#
#  conv2d_346 (Conv2D)            (None, 13, 13, 512)  262656      ['activation_319[0][0]']
#
#  add_49 (Add)                   (None, 13, 13, 512)  0           ['batch_normalization_309[0][0]',
#                                                                   'conv2d_346[0][0]']
#
#  activation_322 (Activation)    (None, 13, 13, 512)  0           ['add_49[0][0]']
#
#  conv2d_351 (Conv2D)            (None, 13, 13, 128)  65664       ['activation_322[0][0]']
#
#  batch_normalization_310 (Batch  (None, 13, 13, 128)  512        ['conv2d_351[0][0]']
#  Normalization)
#
#  activation_323 (Activation)    (None, 13, 13, 128)  0           ['batch_normalization_310[0][0]']
#
#  conv2d_352 (Conv2D)            (None, 13, 13, 128)  147584      ['activation_323[0][0]']
#
#  batch_normalization_311 (Batch  (None, 13, 13, 128)  512        ['conv2d_352[0][0]']
#  Normalization)
#
#  activation_324 (Activation)    (None, 13, 13, 128)  0           ['batch_normalization_311[0][0]']
#
#  conv2d_353 (Conv2D)            (None, 13, 13, 512)  66048       ['activation_324[0][0]']
#
#  batch_normalization_312 (Batch  (None, 13, 13, 512)  2048       ['conv2d_353[0][0]']
#  Normalization)
#
#  conv2d_350 (Conv2D)            (None, 13, 13, 512)  262656      ['activation_322[0][0]']
#
#  add_50 (Add)                   (None, 13, 13, 512)  0           ['batch_normalization_312[0][0]',
#                                                                   'conv2d_350[0][0]']
#
#  activation_325 (Activation)    (None, 13, 13, 512)  0           ['add_50[0][0]']
#
#  conv2d_355 (Conv2D)            (None, 13, 13, 64)   32832       ['activation_325[0][0]']
#
#  batch_normalization_313 (Batch  (None, 13, 13, 64)  256         ['conv2d_355[0][0]']
#  Normalization)
#
#  activation_326 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_313[0][0]']
#
#  conv2d_356 (Conv2D)            (None, 13, 13, 64)   36928       ['activation_326[0][0]']
#
#  batch_normalization_314 (Batch  (None, 13, 13, 64)  256         ['conv2d_356[0][0]']
#  Normalization)
#
#  activation_327 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_314[0][0]']
#
#  conv2d_357 (Conv2D)            (None, 13, 13, 256)  16640       ['activation_327[0][0]']
#
#  batch_normalization_315 (Batch  (None, 13, 13, 256)  1024       ['conv2d_357[0][0]']
#  Normalization)
#
#  conv2d_354 (Conv2D)            (None, 13, 13, 256)  131328      ['activation_325[0][0]']
#
#  add_51 (Add)                   (None, 13, 13, 256)  0           ['batch_normalization_315[0][0]',
#                                                                   'conv2d_354[0][0]']
#
#  activation_328 (Activation)    (None, 13, 13, 256)  0           ['add_51[0][0]']
#
#  conv2d_359 (Conv2D)            (None, 13, 13, 64)   16448       ['activation_328[0][0]']
#
#  batch_normalization_316 (Batch  (None, 13, 13, 64)  256         ['conv2d_359[0][0]']
#  Normalization)
#
#  activation_329 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_316[0][0]']
#
#  conv2d_360 (Conv2D)            (None, 13, 13, 64)   36928       ['activation_329[0][0]']
#
#  batch_normalization_317 (Batch  (None, 13, 13, 64)  256         ['conv2d_360[0][0]']
#  Normalization)
#
#  activation_330 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_317[0][0]']
#
#  conv2d_361 (Conv2D)            (None, 13, 13, 256)  16640       ['activation_330[0][0]']
#
#  batch_normalization_318 (Batch  (None, 13, 13, 256)  1024       ['conv2d_361[0][0]']
#  Normalization)
#
#  conv2d_358 (Conv2D)            (None, 13, 13, 256)  65792       ['activation_328[0][0]']
#
#  add_52 (Add)                   (None, 13, 13, 256)  0           ['batch_normalization_318[0][0]',
#                                                                   'conv2d_358[0][0]']
#
#  activation_331 (Activation)    (None, 13, 13, 256)  0           ['add_52[0][0]']
#
#  conv2d_363 (Conv2D)            (None, 13, 13, 64)   16448       ['activation_331[0][0]']
#
#  batch_normalization_319 (Batch  (None, 13, 13, 64)  256         ['conv2d_363[0][0]']
#  Normalization)
#
#  activation_332 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_319[0][0]']
#
#  conv2d_364 (Conv2D)            (None, 13, 13, 64)   36928       ['activation_332[0][0]']
#
#  batch_normalization_320 (Batch  (None, 13, 13, 64)  256         ['conv2d_364[0][0]']
#  Normalization)
#
#  activation_333 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_320[0][0]']
#
#  conv2d_365 (Conv2D)            (None, 13, 13, 256)  16640       ['activation_333[0][0]']
#
#  batch_normalization_321 (Batch  (None, 13, 13, 256)  1024       ['conv2d_365[0][0]']
#  Normalization)
#
#  conv2d_362 (Conv2D)            (None, 13, 13, 256)  65792       ['activation_331[0][0]']
#
#  add_53 (Add)                   (None, 13, 13, 256)  0           ['batch_normalization_321[0][0]',
#                                                                   'conv2d_362[0][0]']
#
#  activation_334 (Activation)    (None, 13, 13, 256)  0           ['add_53[0][0]']
#
#  conv2d_367 (Conv2D)            (None, 7, 7, 256)    65792       ['activation_334[0][0]']
#
#  batch_normalization_322 (Batch  (None, 7, 7, 256)   1024        ['conv2d_367[0][0]']
#  Normalization)
#
#  activation_335 (Activation)    (None, 7, 7, 256)    0           ['batch_normalization_322[0][0]']
#
#  conv2d_368 (Conv2D)            (None, 7, 7, 256)    590080      ['activation_335[0][0]']
#
#  batch_normalization_323 (Batch  (None, 7, 7, 256)   1024        ['conv2d_368[0][0]']
#  Normalization)
#
#  activation_336 (Activation)    (None, 7, 7, 256)    0           ['batch_normalization_323[0][0]']
#
#  conv2d_369 (Conv2D)            (None, 7, 7, 1024)   263168      ['activation_336[0][0]']
#
#  batch_normalization_324 (Batch  (None, 7, 7, 1024)  4096        ['conv2d_369[0][0]']
#  Normalization)
#
#  conv2d_366 (Conv2D)            (None, 7, 7, 1024)   263168      ['activation_334[0][0]']
#
#  add_54 (Add)                   (None, 7, 7, 1024)   0           ['batch_normalization_324[0][0]',
#                                                                   'conv2d_366[0][0]']
#
#  activation_337 (Activation)    (None, 7, 7, 1024)   0           ['add_54[0][0]']
#
#  conv2d_371 (Conv2D)            (None, 7, 7, 256)    262400      ['activation_337[0][0]']
#
#  batch_normalization_325 (Batch  (None, 7, 7, 256)   1024        ['conv2d_371[0][0]']
#  Normalization)
#
#  activation_338 (Activation)    (None, 7, 7, 256)    0           ['batch_normalization_325[0][0]']
#
#  conv2d_372 (Conv2D)            (None, 7, 7, 256)    590080      ['activation_338[0][0]']
#
#  batch_normalization_326 (Batch  (None, 7, 7, 256)   1024        ['conv2d_372[0][0]']
#  Normalization)
#
#  activation_339 (Activation)    (None, 7, 7, 256)    0           ['batch_normalization_326[0][0]']
#
#  conv2d_373 (Conv2D)            (None, 7, 7, 1024)   263168      ['activation_339[0][0]']
#
#  batch_normalization_327 (Batch  (None, 7, 7, 1024)  4096        ['conv2d_373[0][0]']
#  Normalization)
#
#  conv2d_370 (Conv2D)            (None, 7, 7, 1024)   1049600     ['activation_337[0][0]']
#
#  add_55 (Add)                   (None, 7, 7, 1024)   0           ['batch_normalization_327[0][0]',
#                                                                   'conv2d_370[0][0]']
#
#  activation_340 (Activation)    (None, 7, 7, 1024)   0           ['add_55[0][0]']
#
#  conv2d_375 (Conv2D)            (None, 7, 7, 256)    262400      ['activation_340[0][0]']
#
#  batch_normalization_328 (Batch  (None, 7, 7, 256)   1024        ['conv2d_375[0][0]']
#  Normalization)
#
#  activation_341 (Activation)    (None, 7, 7, 256)    0           ['batch_normalization_328[0][0]']
#
#  conv2d_376 (Conv2D)            (None, 7, 7, 256)    590080      ['activation_341[0][0]']
#
#  batch_normalization_329 (Batch  (None, 7, 7, 256)   1024        ['conv2d_376[0][0]']
#  Normalization)
#
#  activation_342 (Activation)    (None, 7, 7, 256)    0           ['batch_normalization_329[0][0]']
#
#  conv2d_377 (Conv2D)            (None, 7, 7, 1024)   263168      ['activation_342[0][0]']
#
#  batch_normalization_330 (Batch  (None, 7, 7, 1024)  4096        ['conv2d_377[0][0]']
#  Normalization)
#
#  conv2d_374 (Conv2D)            (None, 7, 7, 1024)   1049600     ['activation_340[0][0]']
#
#  add_56 (Add)                   (None, 7, 7, 1024)   0           ['batch_normalization_330[0][0]',
#                                                                   'conv2d_374[0][0]']
#
#  activation_343 (Activation)    (None, 7, 7, 1024)   0           ['add_56[0][0]']
#
#  conv2d_379 (Conv2D)            (None, 7, 7, 256)    262400      ['activation_343[0][0]']
#
#  batch_normalization_331 (Batch  (None, 7, 7, 256)   1024        ['conv2d_379[0][0]']
#  Normalization)
#
#  activation_344 (Activation)    (None, 7, 7, 256)    0           ['batch_normalization_331[0][0]']
#
#  conv2d_380 (Conv2D)            (None, 7, 7, 256)    590080      ['activation_344[0][0]']
#
#  batch_normalization_332 (Batch  (None, 7, 7, 256)   1024        ['conv2d_380[0][0]']
#  Normalization)
#
#  activation_345 (Activation)    (None, 7, 7, 256)    0           ['batch_normalization_332[0][0]']
#
#  conv2d_381 (Conv2D)            (None, 7, 7, 1024)   263168      ['activation_345[0][0]']
#
#  batch_normalization_333 (Batch  (None, 7, 7, 1024)  4096        ['conv2d_381[0][0]']
#  Normalization)
#
#  conv2d_378 (Conv2D)            (None, 7, 7, 1024)   1049600     ['activation_343[0][0]']
#
#  add_57 (Add)                   (None, 7, 7, 1024)   0           ['batch_normalization_333[0][0]',
#                                                                   'conv2d_378[0][0]']
#
#  activation_346 (Activation)    (None, 7, 7, 1024)   0           ['add_57[0][0]']
#
#  conv2d_383 (Conv2D)            (None, 7, 7, 256)    262400      ['activation_346[0][0]']
#
#  batch_normalization_334 (Batch  (None, 7, 7, 256)   1024        ['conv2d_383[0][0]']
#  Normalization)
#
#  activation_347 (Activation)    (None, 7, 7, 256)    0           ['batch_normalization_334[0][0]']
#
#  conv2d_384 (Conv2D)            (None, 7, 7, 256)    590080      ['activation_347[0][0]']
#
#  batch_normalization_335 (Batch  (None, 7, 7, 256)   1024        ['conv2d_384[0][0]']
#  Normalization)
#
#  activation_348 (Activation)    (None, 7, 7, 256)    0           ['batch_normalization_335[0][0]']
#
#  conv2d_385 (Conv2D)            (None, 7, 7, 1024)   263168      ['activation_348[0][0]']
#
#  batch_normalization_336 (Batch  (None, 7, 7, 1024)  4096        ['conv2d_385[0][0]']
#  Normalization)
#
#  conv2d_382 (Conv2D)            (None, 7, 7, 1024)   1049600     ['activation_346[0][0]']
#
#  add_58 (Add)                   (None, 7, 7, 1024)   0           ['batch_normalization_336[0][0]',
#                                                                   'conv2d_382[0][0]']
#
#  activation_349 (Activation)    (None, 7, 7, 1024)   0           ['add_58[0][0]']
#
#  conv2d_387 (Conv2D)            (None, 7, 7, 256)    262400      ['activation_349[0][0]']
#
#  batch_normalization_337 (Batch  (None, 7, 7, 256)   1024        ['conv2d_387[0][0]']
#  Normalization)
#
#  activation_350 (Activation)    (None, 7, 7, 256)    0           ['batch_normalization_337[0][0]']
#
#  conv2d_388 (Conv2D)            (None, 7, 7, 256)    590080      ['activation_350[0][0]']
#
#  batch_normalization_338 (Batch  (None, 7, 7, 256)   1024        ['conv2d_388[0][0]']
#  Normalization)
#
#  activation_351 (Activation)    (None, 7, 7, 256)    0           ['batch_normalization_338[0][0]']
#
#  conv2d_389 (Conv2D)            (None, 7, 7, 1024)   263168      ['activation_351[0][0]']
#
#  batch_normalization_339 (Batch  (None, 7, 7, 1024)  4096        ['conv2d_389[0][0]']
#  Normalization)
#
#  conv2d_386 (Conv2D)            (None, 7, 7, 1024)   1049600     ['activation_349[0][0]']
#
#  add_59 (Add)                   (None, 7, 7, 1024)   0           ['batch_normalization_339[0][0]',
#                                                                   'conv2d_386[0][0]']
#
#  activation_352 (Activation)    (None, 7, 7, 1024)   0           ['add_59[0][0]']
#
#  conv2d_391 (Conv2D)            (None, 7, 7, 64)     65600       ['activation_352[0][0]']
#
#  batch_normalization_340 (Batch  (None, 7, 7, 64)    256         ['conv2d_391[0][0]']
#  Normalization)
#
#  activation_353 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_340[0][0]']
#
#  conv2d_392 (Conv2D)            (None, 7, 7, 64)     36928       ['activation_353[0][0]']
#
#  batch_normalization_341 (Batch  (None, 7, 7, 64)    256         ['conv2d_392[0][0]']
#  Normalization)
#
#  activation_354 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_341[0][0]']
#
#  conv2d_393 (Conv2D)            (None, 7, 7, 256)    16640       ['activation_354[0][0]']
#
#  batch_normalization_342 (Batch  (None, 7, 7, 256)   1024        ['conv2d_393[0][0]']
#  Normalization)
#
#  conv2d_390 (Conv2D)            (None, 7, 7, 256)    262400      ['activation_352[0][0]']
#
#  add_60 (Add)                   (None, 7, 7, 256)    0           ['batch_normalization_342[0][0]',
#                                                                   'conv2d_390[0][0]']
#
#  activation_355 (Activation)    (None, 7, 7, 256)    0           ['add_60[0][0]']
#
#  conv2d_395 (Conv2D)            (None, 7, 7, 64)     16448       ['activation_355[0][0]']
#
#  batch_normalization_343 (Batch  (None, 7, 7, 64)    256         ['conv2d_395[0][0]']
#  Normalization)
#
#  activation_356 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_343[0][0]']
#
#  conv2d_396 (Conv2D)            (None, 7, 7, 64)     36928       ['activation_356[0][0]']
#
#  batch_normalization_344 (Batch  (None, 7, 7, 64)    256         ['conv2d_396[0][0]']
#  Normalization)
#
#  activation_357 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_344[0][0]']
#
#  conv2d_397 (Conv2D)            (None, 7, 7, 256)    16640       ['activation_357[0][0]']
#
#  batch_normalization_345 (Batch  (None, 7, 7, 256)   1024        ['conv2d_397[0][0]']
#  Normalization)
#
#  conv2d_394 (Conv2D)            (None, 7, 7, 256)    65792       ['activation_355[0][0]']
#
#  add_61 (Add)                   (None, 7, 7, 256)    0           ['batch_normalization_345[0][0]',
#                                                                   'conv2d_394[0][0]']
#
#  activation_358 (Activation)    (None, 7, 7, 256)    0           ['add_61[0][0]']
#
#  conv2d_399 (Conv2D)            (None, 7, 7, 64)     16448       ['activation_358[0][0]']
#
#  batch_normalization_346 (Batch  (None, 7, 7, 64)    256         ['conv2d_399[0][0]']
#  Normalization)
#
#  activation_359 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_346[0][0]']
#
#  conv2d_400 (Conv2D)            (None, 7, 7, 64)     36928       ['activation_359[0][0]']
#
#  batch_normalization_347 (Batch  (None, 7, 7, 64)    256         ['conv2d_400[0][0]']
#  Normalization)
#
#  activation_360 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_347[0][0]']
#
#  conv2d_401 (Conv2D)            (None, 7, 7, 256)    16640       ['activation_360[0][0]']
#
#  batch_normalization_348 (Batch  (None, 7, 7, 256)   1024        ['conv2d_401[0][0]']
#  Normalization)
#
#  conv2d_398 (Conv2D)            (None, 7, 7, 256)    65792       ['activation_358[0][0]']
#
#  add_62 (Add)                   (None, 7, 7, 256)    0           ['batch_normalization_348[0][0]',
#                                                                   'conv2d_398[0][0]']
#
#  activation_361 (Activation)    (None, 7, 7, 256)    0           ['add_62[0][0]']
#
#  conv2d_403 (Conv2D)            (None, 4, 4, 512)    131584      ['activation_361[0][0]']
#
#  batch_normalization_349 (Batch  (None, 4, 4, 512)   2048        ['conv2d_403[0][0]']
#  Normalization)
#
#  activation_362 (Activation)    (None, 4, 4, 512)    0           ['batch_normalization_349[0][0]']
#
#  conv2d_404 (Conv2D)            (None, 4, 4, 512)    2359808     ['activation_362[0][0]']
#
#  batch_normalization_350 (Batch  (None, 4, 4, 512)   2048        ['conv2d_404[0][0]']
#  Normalization)
#
#  activation_363 (Activation)    (None, 4, 4, 512)    0           ['batch_normalization_350[0][0]']
#
#  conv2d_405 (Conv2D)            (None, 4, 4, 2048)   1050624     ['activation_363[0][0]']
#
#  batch_normalization_351 (Batch  (None, 4, 4, 2048)  8192        ['conv2d_405[0][0]']
#  Normalization)
#
#  conv2d_402 (Conv2D)            (None, 4, 4, 2048)   526336      ['activation_361[0][0]']
#
#  add_63 (Add)                   (None, 4, 4, 2048)   0           ['batch_normalization_351[0][0]',
#                                                                   'conv2d_402[0][0]']
#
#  activation_364 (Activation)    (None, 4, 4, 2048)   0           ['add_63[0][0]']
#
#  conv2d_407 (Conv2D)            (None, 4, 4, 512)    1049088     ['activation_364[0][0]']
#
#  batch_normalization_352 (Batch  (None, 4, 4, 512)   2048        ['conv2d_407[0][0]']
#  Normalization)
#
#  activation_365 (Activation)    (None, 4, 4, 512)    0           ['batch_normalization_352[0][0]']
#
#  conv2d_408 (Conv2D)            (None, 4, 4, 512)    2359808     ['activation_365[0][0]']
#
#  batch_normalization_353 (Batch  (None, 4, 4, 512)   2048        ['conv2d_408[0][0]']
#  Normalization)
#
#  activation_366 (Activation)    (None, 4, 4, 512)    0           ['batch_normalization_353[0][0]']
#
#  conv2d_409 (Conv2D)            (None, 4, 4, 2048)   1050624     ['activation_366[0][0]']
#
#  batch_normalization_354 (Batch  (None, 4, 4, 2048)  8192        ['conv2d_409[0][0]']
#  Normalization)
#
#  conv2d_406 (Conv2D)            (None, 4, 4, 2048)   4196352     ['activation_364[0][0]']
#
#  add_64 (Add)                   (None, 4, 4, 2048)   0           ['batch_normalization_354[0][0]',
#                                                                   'conv2d_406[0][0]']
#
#  activation_367 (Activation)    (None, 4, 4, 2048)   0           ['add_64[0][0]']
#
#  conv2d_411 (Conv2D)            (None, 4, 4, 512)    1049088     ['activation_367[0][0]']
#
#  batch_normalization_355 (Batch  (None, 4, 4, 512)   2048        ['conv2d_411[0][0]']
#  Normalization)
#
#  activation_368 (Activation)    (None, 4, 4, 512)    0           ['batch_normalization_355[0][0]']
#
#  conv2d_412 (Conv2D)            (None, 4, 4, 512)    2359808     ['activation_368[0][0]']
#
#  batch_normalization_356 (Batch  (None, 4, 4, 512)   2048        ['conv2d_412[0][0]']
#  Normalization)
#
#  activation_369 (Activation)    (None, 4, 4, 512)    0           ['batch_normalization_356[0][0]']
#
#  conv2d_413 (Conv2D)            (None, 4, 4, 2048)   1050624     ['activation_369[0][0]']
#
#  batch_normalization_357 (Batch  (None, 4, 4, 2048)  8192        ['conv2d_413[0][0]']
#  Normalization)
#
#  conv2d_410 (Conv2D)            (None, 4, 4, 2048)   4196352     ['activation_367[0][0]']
#
#  add_65 (Add)                   (None, 4, 4, 2048)   0           ['batch_normalization_357[0][0]',
#                                                                   'conv2d_410[0][0]']
#
#  activation_370 (Activation)    (None, 4, 4, 2048)   0           ['add_65[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 2, 2, 2048)  0           ['activation_370[0][0]']
#  oling2D)
#
#  flatten_5 (Flatten)            (None, 8192)         0           ['average_pooling2d_5[0][0]']
#
#  dense_5 (Dense)                (None, 1000)         8193000     ['flatten_5[0][0]']
#
# ==================================================================================================
# Total params: 45,183,592
# Trainable params: 45,133,544
# Non-trainable params: 50,048
# __________________________________________________________________________________________________

# %%
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt

# %%
# Tensorflow-datasets의 Cats vs Dogs 데이터셋 로드
(ds_train, ds_test), ds_info = tfds.load(
    'cats_vs_dogs',
    split=['train[:75%]', 'train[75%:]'],
    shuffle_files=True,
    with_info=True,
    as_supervised=True
)

# 훈련 데이터와 검증 데이터의 크기
print(tf.data.experimental.cardinality(ds_train))
print(tf.data.experimental.cardinality(ds_test))
# Out:
# tf.Tensor(17446, shape=(), dtype=int64)
# tf.Tensor(5816, shape=(), dtype=int64)

# %%
# 데이터를 정규화하고 이미지 크기를 통일시키는 함수 작성
def normalize_n_resize_img(image, label):
    image = tf.image.resize(image, [100, 100])
    image = (image / 255.0)
    return image, label

# 데이터셋에 위 함수를 적용하는 함수 작성
def apply_normalize_on_dataset(ds, is_test=False, batch_size=16):
    ds = ds.map(
        normalize_n_resize_img,
        num_parallel_calls=1
    )
    ds = ds.batch(batch_size)
    if not is_test:
        ds = ds.repeat()
        ds = ds.shuffle(200)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
    return ds

# %%
# 훈련 데이터의 예시를 출력
fig = tfds.show_examples(ds_train, ds_info)

# %%
# batch 크기와 epoch를 지정, 훈련 데이터와 검증 데이터에 정규화 함수 적용
BATCH_SIZE = 64
EPOCH = 15

ds_train = apply_normalize_on_dataset(ds_train, batch_size=BATCH_SIZE)
ds_test = apply_normalize_on_dataset(ds_test, batch_size=BATCH_SIZE)

# %%
# ResNet-34 모델을 컴파일하고 학습 진행
resnet_34.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

history_34 = resnet_34.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:75%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[75%:90%]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/15
# c:\Users\ZAKAR\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 272/272 [==============================] - 37s 93ms/step - loss: 1.0003 - accuracy: 0.5222 - val_loss: 0.8310 - val_accuracy: 0.5168
# Epoch 2/15
# 272/272 [==============================] - 26s 95ms/step - loss: 0.7585 - accuracy: 0.5917 - val_loss: 0.8066 - val_accuracy: 0.5522
# Epoch 3/15
# 272/272 [==============================] - 24s 90ms/step - loss: 0.7126 - accuracy: 0.6174 - val_loss: 0.7316 - val_accuracy: 0.5887
# Epoch 4/15
# 272/272 [==============================] - 24s 88ms/step - loss: 0.6723 - accuracy: 0.6487 - val_loss: 0.7907 - val_accuracy: 0.6253
# Epoch 5/15
# 272/272 [==============================] - 24s 88ms/step - loss: 0.6496 - accuracy: 0.6656 - val_loss: 0.7955 - val_accuracy: 0.6233
# Epoch 6/15
# 272/272 [==============================] - 24s 89ms/step - loss: 0.6167 - accuracy: 0.6895 - val_loss: 0.8051 - val_accuracy: 0.5969
# Epoch 7/15
# 272/272 [==============================] - 24s 89ms/step - loss: 0.5704 - accuracy: 0.7143 - val_loss: 0.6664 - val_accuracy: 0.7010
# Epoch 8/15
# 272/272 [==============================] - 24s 89ms/step - loss: 0.5275 - accuracy: 0.7455 - val_loss: 0.8039 - val_accuracy: 0.6734
# Epoch 9/15
# 272/272 [==============================] - 24s 89ms/step - loss: 0.4685 - accuracy: 0.7820 - val_loss: 0.6326 - val_accuracy: 0.6995
# Epoch 10/15
# 272/272 [==============================] - 24s 89ms/step - loss: 0.4289 - accuracy: 0.8041 - val_loss: 0.6007 - val_accuracy: 0.7170
# Epoch 11/15
# 272/272 [==============================] - 24s 88ms/step - loss: 0.3669 - accuracy: 0.8405 - val_loss: 0.6138 - val_accuracy: 0.7538
# Epoch 12/15
# 272/272 [==============================] - 24s 88ms/step - loss: 0.3117 - accuracy: 0.8652 - val_loss: 0.6439 - val_accuracy: 0.7462
# Epoch 13/15
# 272/272 [==============================] - 24s 88ms/step - loss: 0.2595 - accuracy: 0.8905 - val_loss: 0.9510 - val_accuracy: 0.6772
# Epoch 14/15
# 272/272 [==============================] - 24s 88ms/step - loss: 0.1993 - accuracy: 0.9172 - val_loss: 0.8582 - val_accuracy: 0.7323
# Epoch 15/15
# 272/272 [==============================] - 24s 89ms/step - loss: 0.1733 - accuracy: 0.9309 - val_loss: 0.9113 - val_accuracy: 0.7361

# %%
# ResNet-50 모델을 컴파일하고 학습 진행
resnet_50.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

history_50 = resnet_50.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:75%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[75%:90%]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/15
# c:\Users\ZAKAR\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 272/272 [==============================] - 51s 152ms/step - loss: 0.9813 - accuracy: 0.5009 - val_loss: 0.8281 - val_accuracy: 0.4841
# Epoch 2/15
# 272/272 [==============================] - 40s 149ms/step - loss: 0.7803 - accuracy: 0.5020 - val_loss: 0.7068 - val_accuracy: 0.4962
# Epoch 3/15
# 272/272 [==============================] - 40s 149ms/step - loss: 0.7678 - accuracy: 0.5089 - val_loss: 1.1539 - val_accuracy: 0.4985
# Epoch 4/15
# 272/272 [==============================] - 40s 149ms/step - loss: 0.7591 - accuracy: 0.5070 - val_loss: 1.4437 - val_accuracy: 0.4878
# Epoch 5/15
# 272/272 [==============================] - 41s 151ms/step - loss: 0.7572 - accuracy: 0.5092 - val_loss: 1.2571 - val_accuracy: 0.5067
# Epoch 6/15
# 272/272 [==============================] - 41s 149ms/step - loss: 0.7584 - accuracy: 0.5048 - val_loss: 1.3304 - val_accuracy: 0.5405
# Epoch 7/15
# 272/272 [==============================] - 40s 149ms/step - loss: 0.7494 - accuracy: 0.5054 - val_loss: 1.8372 - val_accuracy: 0.4634
# Epoch 8/15
# 272/272 [==============================] - 40s 149ms/step - loss: 0.7448 - accuracy: 0.5113 - val_loss: 0.7576 - val_accuracy: 0.5411
# Epoch 9/15
# 272/272 [==============================] - 41s 149ms/step - loss: 0.7414 - accuracy: 0.5201 - val_loss: 0.7099 - val_accuracy: 0.5183
# Epoch 10/15
# 272/272 [==============================] - 41s 149ms/step - loss: 0.7354 - accuracy: 0.5228 - val_loss: 1.0288 - val_accuracy: 0.5267
# Epoch 11/15
# 272/272 [==============================] - 40s 148ms/step - loss: 0.7356 - accuracy: 0.5162 - val_loss: 0.9678 - val_accuracy: 0.5110
# Epoch 12/15
# 272/272 [==============================] - 41s 149ms/step - loss: 0.7313 - accuracy: 0.5211 - val_loss: 0.9000 - val_accuracy: 0.5278
# Epoch 13/15
# 272/272 [==============================] - 40s 149ms/step - loss: 0.7348 - accuracy: 0.5133 - val_loss: 0.7136 - val_accuracy: 0.5392
# Epoch 14/15
# 272/272 [==============================] - 41s 149ms/step - loss: 0.7258 - accuracy: 0.5216 - val_loss: 0.8302 - val_accuracy: 0.5130
# Epoch 15/15
# 272/272 [==============================] - 40s 149ms/step - loss: 0.7231 - accuracy: 0.5212 - val_loss: 0.7053 - val_accuracy: 0.5168

# %%
# ResNet-34 plain 모델을 만들고 요약
resnet_34_plain = build_resnet(input_shape=(100, 100, 3), is_50=False, is_plain=True)
resnet_34_plain.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 100, 100, 3)]     0
#
#  conv2d_280 (Conv2D)         (None, 50, 50, 64)        9472
#
#  batch_normalization_246 (Ba  (None, 50, 50, 64)       256
#  tchNormalization)
#
#  activation_259 (Activation)  (None, 50, 50, 64)       0
#
#  max_pooling2d_4 (MaxPooling  (None, 25, 25, 64)       0
#  2D)
#
#  conv2d_281 (Conv2D)         (None, 25, 25, 64)        36928
#
#  batch_normalization_247 (Ba  (None, 25, 25, 64)       256
#  tchNormalization)
#
#  activation_260 (Activation)  (None, 25, 25, 64)       0
#
#  conv2d_282 (Conv2D)         (None, 25, 25, 64)        36928
#
#  batch_normalization_248 (Ba  (None, 25, 25, 64)       256
#  tchNormalization)
#
#  activation_261 (Activation)  (None, 25, 25, 64)       0
#
#  conv2d_283 (Conv2D)         (None, 25, 25, 64)        36928
#
#  batch_normalization_249 (Ba  (None, 25, 25, 64)       256
#  tchNormalization)
#
#  activation_262 (Activation)  (None, 25, 25, 64)       0
#
#  conv2d_284 (Conv2D)         (None, 25, 25, 64)        36928
#
#  batch_normalization_250 (Ba  (None, 25, 25, 64)       256
#  tchNormalization)
#
#  activation_263 (Activation)  (None, 25, 25, 64)       0
#
#  conv2d_285 (Conv2D)         (None, 25, 25, 64)        36928
#
#  batch_normalization_251 (Ba  (None, 25, 25, 64)       256
#  tchNormalization)
#
#  activation_264 (Activation)  (None, 25, 25, 64)       0
#
#  conv2d_286 (Conv2D)         (None, 25, 25, 64)        36928
#
#  batch_normalization_252 (Ba  (None, 25, 25, 64)       256
#  tchNormalization)
#
#  activation_265 (Activation)  (None, 25, 25, 64)       0
#
#  conv2d_287 (Conv2D)         (None, 13, 13, 128)       73856
#
#  batch_normalization_253 (Ba  (None, 13, 13, 128)      512
#  tchNormalization)
#
#  activation_266 (Activation)  (None, 13, 13, 128)      0
#
#  conv2d_288 (Conv2D)         (None, 13, 13, 128)       147584
#
#  batch_normalization_254 (Ba  (None, 13, 13, 128)      512
#  tchNormalization)
#
#  activation_267 (Activation)  (None, 13, 13, 128)      0
#
#  conv2d_289 (Conv2D)         (None, 13, 13, 128)       147584
#
#  batch_normalization_255 (Ba  (None, 13, 13, 128)      512
#  tchNormalization)
#
#  activation_268 (Activation)  (None, 13, 13, 128)      0
#
#  conv2d_290 (Conv2D)         (None, 13, 13, 128)       147584
#
#  batch_normalization_256 (Ba  (None, 13, 13, 128)      512
#  tchNormalization)
#
#  activation_269 (Activation)  (None, 13, 13, 128)      0
#
#  conv2d_291 (Conv2D)         (None, 13, 13, 128)       147584
#
#  batch_normalization_257 (Ba  (None, 13, 13, 128)      512
#  tchNormalization)
#
#  activation_270 (Activation)  (None, 13, 13, 128)      0
#
#  conv2d_292 (Conv2D)         (None, 13, 13, 128)       147584
#
#  batch_normalization_258 (Ba  (None, 13, 13, 128)      512
#  tchNormalization)
#
#  activation_271 (Activation)  (None, 13, 13, 128)      0
#
#  conv2d_293 (Conv2D)         (None, 13, 13, 128)       147584
#
#  batch_normalization_259 (Ba  (None, 13, 13, 128)      512
#  tchNormalization)
#
#  activation_272 (Activation)  (None, 13, 13, 128)      0
#
#  conv2d_294 (Conv2D)         (None, 13, 13, 128)       147584
#
#  batch_normalization_260 (Ba  (None, 13, 13, 128)      512
#  tchNormalization)
#
#  activation_273 (Activation)  (None, 13, 13, 128)      0
#
#  conv2d_295 (Conv2D)         (None, 13, 13, 64)        73792
#
#  batch_normalization_261 (Ba  (None, 13, 13, 64)       256
#  tchNormalization)
#
#  activation_274 (Activation)  (None, 13, 13, 64)       0
#
#  conv2d_296 (Conv2D)         (None, 13, 13, 64)        36928
#
#  batch_normalization_262 (Ba  (None, 13, 13, 64)       256
#  tchNormalization)
#
#  activation_275 (Activation)  (None, 13, 13, 64)       0
#
#  conv2d_297 (Conv2D)         (None, 13, 13, 64)        36928
#
#  batch_normalization_263 (Ba  (None, 13, 13, 64)       256
#  tchNormalization)
#
#  activation_276 (Activation)  (None, 13, 13, 64)       0
#
#  conv2d_298 (Conv2D)         (None, 13, 13, 64)        36928
#
#  batch_normalization_264 (Ba  (None, 13, 13, 64)       256
#  tchNormalization)
#
#  activation_277 (Activation)  (None, 13, 13, 64)       0
#
#  conv2d_299 (Conv2D)         (None, 13, 13, 64)        36928
#
#  batch_normalization_265 (Ba  (None, 13, 13, 64)       256
#  tchNormalization)
#
#  activation_278 (Activation)  (None, 13, 13, 64)       0
#
#  conv2d_300 (Conv2D)         (None, 13, 13, 64)        36928
#
#  batch_normalization_266 (Ba  (None, 13, 13, 64)       256
#  tchNormalization)
#
#  activation_279 (Activation)  (None, 13, 13, 64)       0
#
#  conv2d_301 (Conv2D)         (None, 7, 7, 256)         147712
#
#  batch_normalization_267 (Ba  (None, 7, 7, 256)        1024
#  tchNormalization)
#
#  activation_280 (Activation)  (None, 7, 7, 256)        0
#
#  conv2d_302 (Conv2D)         (None, 7, 7, 256)         590080
#
#  batch_normalization_268 (Ba  (None, 7, 7, 256)        1024
#  tchNormalization)
#
#  activation_281 (Activation)  (None, 7, 7, 256)        0
#
#  conv2d_303 (Conv2D)         (None, 7, 7, 256)         590080
#
#  batch_normalization_269 (Ba  (None, 7, 7, 256)        1024
#  tchNormalization)
#
#  activation_282 (Activation)  (None, 7, 7, 256)        0
#
#  conv2d_304 (Conv2D)         (None, 7, 7, 256)         590080
#
#  batch_normalization_270 (Ba  (None, 7, 7, 256)        1024
#  tchNormalization)
#
#  activation_283 (Activation)  (None, 7, 7, 256)        0
#
#  conv2d_305 (Conv2D)         (None, 7, 7, 256)         590080
#
#  batch_normalization_271 (Ba  (None, 7, 7, 256)        1024
#  tchNormalization)
#
#  activation_284 (Activation)  (None, 7, 7, 256)        0
#
#  conv2d_306 (Conv2D)         (None, 7, 7, 256)         590080
#
#  batch_normalization_272 (Ba  (None, 7, 7, 256)        1024
#  tchNormalization)
#
#  activation_285 (Activation)  (None, 7, 7, 256)        0
#
#  conv2d_307 (Conv2D)         (None, 7, 7, 256)         590080
#
#  batch_normalization_273 (Ba  (None, 7, 7, 256)        1024
#  tchNormalization)
#
#  activation_286 (Activation)  (None, 7, 7, 256)        0
#
#  conv2d_308 (Conv2D)         (None, 7, 7, 256)         590080
#
#  batch_normalization_274 (Ba  (None, 7, 7, 256)        1024
#  tchNormalization)
#
#  activation_287 (Activation)  (None, 7, 7, 256)        0
#
#  conv2d_309 (Conv2D)         (None, 7, 7, 256)         590080
#
#  batch_normalization_275 (Ba  (None, 7, 7, 256)        1024
#  tchNormalization)
#
#  activation_288 (Activation)  (None, 7, 7, 256)        0
#
#  conv2d_310 (Conv2D)         (None, 7, 7, 256)         590080
#
#  batch_normalization_276 (Ba  (None, 7, 7, 256)        1024
#  tchNormalization)
#
#  activation_289 (Activation)  (None, 7, 7, 256)        0
#
#  conv2d_311 (Conv2D)         (None, 7, 7, 256)         590080
#
#  batch_normalization_277 (Ba  (None, 7, 7, 256)        1024
#  tchNormalization)
#
#  activation_290 (Activation)  (None, 7, 7, 256)        0
#
#  conv2d_312 (Conv2D)         (None, 7, 7, 256)         590080
#
#  batch_normalization_278 (Ba  (None, 7, 7, 256)        1024
#  tchNormalization)
#
#  activation_291 (Activation)  (None, 7, 7, 256)        0
#
#  conv2d_313 (Conv2D)         (None, 7, 7, 64)          147520
#
#  batch_normalization_279 (Ba  (None, 7, 7, 64)         256
#  tchNormalization)
#
#  activation_292 (Activation)  (None, 7, 7, 64)         0
#
#  conv2d_314 (Conv2D)         (None, 7, 7, 64)          36928
#
#  batch_normalization_280 (Ba  (None, 7, 7, 64)         256
#  tchNormalization)
#
#  activation_293 (Activation)  (None, 7, 7, 64)         0
#
#  conv2d_315 (Conv2D)         (None, 7, 7, 64)          36928
#
#  batch_normalization_281 (Ba  (None, 7, 7, 64)         256
#  tchNormalization)
#
#  activation_294 (Activation)  (None, 7, 7, 64)         0
#
#  conv2d_316 (Conv2D)         (None, 7, 7, 64)          36928
#
#  batch_normalization_282 (Ba  (None, 7, 7, 64)         256
#  tchNormalization)
#
#  activation_295 (Activation)  (None, 7, 7, 64)         0
#
#  conv2d_317 (Conv2D)         (None, 7, 7, 64)          36928
#
#  batch_normalization_283 (Ba  (None, 7, 7, 64)         256
#  tchNormalization)
#
#  activation_296 (Activation)  (None, 7, 7, 64)         0
#
#  conv2d_318 (Conv2D)         (None, 7, 7, 64)          36928
#
#  batch_normalization_284 (Ba  (None, 7, 7, 64)         256
#  tchNormalization)
#
#  activation_297 (Activation)  (None, 7, 7, 64)         0
#
#  conv2d_319 (Conv2D)         (None, 4, 4, 512)         295424
#
#  batch_normalization_285 (Ba  (None, 4, 4, 512)        2048
#  tchNormalization)
#
#  activation_298 (Activation)  (None, 4, 4, 512)        0
#
#  conv2d_320 (Conv2D)         (None, 4, 4, 512)         2359808
#
#  batch_normalization_286 (Ba  (None, 4, 4, 512)        2048
#  tchNormalization)
#
#  activation_299 (Activation)  (None, 4, 4, 512)        0
#
#  conv2d_321 (Conv2D)         (None, 4, 4, 512)         2359808
#
#  batch_normalization_287 (Ba  (None, 4, 4, 512)        2048
#  tchNormalization)
#
#  activation_300 (Activation)  (None, 4, 4, 512)        0
#
#  conv2d_322 (Conv2D)         (None, 4, 4, 512)         2359808
#
#  batch_normalization_288 (Ba  (None, 4, 4, 512)        2048
#  tchNormalization)
#
#  activation_301 (Activation)  (None, 4, 4, 512)        0
#
#  conv2d_323 (Conv2D)         (None, 4, 4, 512)         2359808
#
#  batch_normalization_289 (Ba  (None, 4, 4, 512)        2048
#  tchNormalization)
#
#  activation_302 (Activation)  (None, 4, 4, 512)        0
#
#  conv2d_324 (Conv2D)         (None, 4, 4, 512)         2359808
#
#  batch_normalization_290 (Ba  (None, 4, 4, 512)        2048
#  tchNormalization)
#
#  activation_303 (Activation)  (None, 4, 4, 512)        0
#
#  average_pooling2d_4 (Averag  (None, 2, 2, 512)        0
#  ePooling2D)
#
#  flatten_4 (Flatten)         (None, 2048)              0
#
#  dense_4 (Dense)             (None, 1000)              2049000
#
# =================================================================
# Total params: 22,744,168
# Trainable params: 22,727,400
# Non-trainable params: 16,768
# _________________________________________________________________

# %%
# ResNet-50 plain 모델을 만들고 요약
resnet_50_plain = build_resnet(input_shape=(100, 100, 3), is_50=True, is_plain=True)
resnet_50_plain.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 100, 100, 3)]     0
#
#  conv2d_414 (Conv2D)         (None, 50, 50, 64)        9472
#
#  batch_normalization_358 (Ba  (None, 50, 50, 64)       256
#  tchNormalization)
#
#  activation_371 (Activation)  (None, 50, 50, 64)       0
#
#  max_pooling2d_6 (MaxPooling  (None, 25, 25, 64)       0
#  2D)
#
#  conv2d_415 (Conv2D)         (None, 25, 25, 64)        4160
#
#  batch_normalization_359 (Ba  (None, 25, 25, 64)       256
#  tchNormalization)
#
#  activation_372 (Activation)  (None, 25, 25, 64)       0
#
#  conv2d_416 (Conv2D)         (None, 25, 25, 64)        36928
#
#  batch_normalization_360 (Ba  (None, 25, 25, 64)       256
#  tchNormalization)
#
#  activation_373 (Activation)  (None, 25, 25, 64)       0
#
#  conv2d_417 (Conv2D)         (None, 25, 25, 256)       16640
#
#  batch_normalization_361 (Ba  (None, 25, 25, 256)      1024
#  tchNormalization)
#
#  activation_374 (Activation)  (None, 25, 25, 256)      0
#
#  conv2d_418 (Conv2D)         (None, 25, 25, 64)        16448
#
#  batch_normalization_362 (Ba  (None, 25, 25, 64)       256
#  tchNormalization)
#
#  activation_375 (Activation)  (None, 25, 25, 64)       0
#
#  conv2d_419 (Conv2D)         (None, 25, 25, 64)        36928
#
#  batch_normalization_363 (Ba  (None, 25, 25, 64)       256
#  tchNormalization)
#
#  activation_376 (Activation)  (None, 25, 25, 64)       0
#
#  conv2d_420 (Conv2D)         (None, 25, 25, 256)       16640
#
#  batch_normalization_364 (Ba  (None, 25, 25, 256)      1024
#  tchNormalization)
#
#  activation_377 (Activation)  (None, 25, 25, 256)      0
#
#  conv2d_421 (Conv2D)         (None, 25, 25, 64)        16448
#
#  batch_normalization_365 (Ba  (None, 25, 25, 64)       256
#  tchNormalization)
#
#  activation_378 (Activation)  (None, 25, 25, 64)       0
#
#  conv2d_422 (Conv2D)         (None, 25, 25, 64)        36928
#
#  batch_normalization_366 (Ba  (None, 25, 25, 64)       256
#  tchNormalization)
#
#  activation_379 (Activation)  (None, 25, 25, 64)       0
#
#  conv2d_423 (Conv2D)         (None, 25, 25, 256)       16640
#
#  batch_normalization_367 (Ba  (None, 25, 25, 256)      1024
#  tchNormalization)
#
#  activation_380 (Activation)  (None, 25, 25, 256)      0
#
#  conv2d_424 (Conv2D)         (None, 13, 13, 128)       32896
#
#  batch_normalization_368 (Ba  (None, 13, 13, 128)      512
#  tchNormalization)
#
#  activation_381 (Activation)  (None, 13, 13, 128)      0
#
#  conv2d_425 (Conv2D)         (None, 13, 13, 128)       147584
#
#  batch_normalization_369 (Ba  (None, 13, 13, 128)      512
#  tchNormalization)
#
#  activation_382 (Activation)  (None, 13, 13, 128)      0
#
#  conv2d_426 (Conv2D)         (None, 13, 13, 512)       66048
#
#  batch_normalization_370 (Ba  (None, 13, 13, 512)      2048
#  tchNormalization)
#
#  activation_383 (Activation)  (None, 13, 13, 512)      0
#
#  conv2d_427 (Conv2D)         (None, 13, 13, 128)       65664
#
#  batch_normalization_371 (Ba  (None, 13, 13, 128)      512
#  tchNormalization)
#
#  activation_384 (Activation)  (None, 13, 13, 128)      0
#
#  conv2d_428 (Conv2D)         (None, 13, 13, 128)       147584
#
#  batch_normalization_372 (Ba  (None, 13, 13, 128)      512
#  tchNormalization)
#
#  activation_385 (Activation)  (None, 13, 13, 128)      0
#
#  conv2d_429 (Conv2D)         (None, 13, 13, 512)       66048
#
#  batch_normalization_373 (Ba  (None, 13, 13, 512)      2048
#  tchNormalization)
#
#  activation_386 (Activation)  (None, 13, 13, 512)      0
#
#  conv2d_430 (Conv2D)         (None, 13, 13, 128)       65664
#
#  batch_normalization_374 (Ba  (None, 13, 13, 128)      512
#  tchNormalization)
#
#  activation_387 (Activation)  (None, 13, 13, 128)      0
#
#  conv2d_431 (Conv2D)         (None, 13, 13, 128)       147584
#
#  batch_normalization_375 (Ba  (None, 13, 13, 128)      512
#  tchNormalization)
#
#  activation_388 (Activation)  (None, 13, 13, 128)      0
#
#  conv2d_432 (Conv2D)         (None, 13, 13, 512)       66048
#
#  batch_normalization_376 (Ba  (None, 13, 13, 512)      2048
#  tchNormalization)
#
#  activation_389 (Activation)  (None, 13, 13, 512)      0
#
#  conv2d_433 (Conv2D)         (None, 13, 13, 128)       65664
#
#  batch_normalization_377 (Ba  (None, 13, 13, 128)      512
#  tchNormalization)
#
#  activation_390 (Activation)  (None, 13, 13, 128)      0
#
#  conv2d_434 (Conv2D)         (None, 13, 13, 128)       147584
#
#  batch_normalization_378 (Ba  (None, 13, 13, 128)      512
#  tchNormalization)
#
#  activation_391 (Activation)  (None, 13, 13, 128)      0
#
#  conv2d_435 (Conv2D)         (None, 13, 13, 512)       66048
#
#  batch_normalization_379 (Ba  (None, 13, 13, 512)      2048
#  tchNormalization)
#
#  activation_392 (Activation)  (None, 13, 13, 512)      0
#
#  conv2d_436 (Conv2D)         (None, 13, 13, 64)        32832
#
#  batch_normalization_380 (Ba  (None, 13, 13, 64)       256
#  tchNormalization)
#
#  activation_393 (Activation)  (None, 13, 13, 64)       0
#
#  conv2d_437 (Conv2D)         (None, 13, 13, 64)        36928
#
#  batch_normalization_381 (Ba  (None, 13, 13, 64)       256
#  tchNormalization)
#
#  activation_394 (Activation)  (None, 13, 13, 64)       0
#
#  conv2d_438 (Conv2D)         (None, 13, 13, 256)       16640
#
#  batch_normalization_382 (Ba  (None, 13, 13, 256)      1024
#  tchNormalization)
#
#  activation_395 (Activation)  (None, 13, 13, 256)      0
#
#  conv2d_439 (Conv2D)         (None, 13, 13, 64)        16448
#
#  batch_normalization_383 (Ba  (None, 13, 13, 64)       256
#  tchNormalization)
#
#  activation_396 (Activation)  (None, 13, 13, 64)       0
#
#  conv2d_440 (Conv2D)         (None, 13, 13, 64)        36928
#
#  batch_normalization_384 (Ba  (None, 13, 13, 64)       256
#  tchNormalization)
#
#  activation_397 (Activation)  (None, 13, 13, 64)       0
#
#  conv2d_441 (Conv2D)         (None, 13, 13, 256)       16640
#
#  batch_normalization_385 (Ba  (None, 13, 13, 256)      1024
#  tchNormalization)
#
#  activation_398 (Activation)  (None, 13, 13, 256)      0
#
#  conv2d_442 (Conv2D)         (None, 13, 13, 64)        16448
#
#  batch_normalization_386 (Ba  (None, 13, 13, 64)       256
#  tchNormalization)
#
#  activation_399 (Activation)  (None, 13, 13, 64)       0
#
#  conv2d_443 (Conv2D)         (None, 13, 13, 64)        36928
#
#  batch_normalization_387 (Ba  (None, 13, 13, 64)       256
#  tchNormalization)
#
#  activation_400 (Activation)  (None, 13, 13, 64)       0
#
#  conv2d_444 (Conv2D)         (None, 13, 13, 256)       16640
#
#  batch_normalization_388 (Ba  (None, 13, 13, 256)      1024
#  tchNormalization)
#
#  activation_401 (Activation)  (None, 13, 13, 256)      0
#
#  conv2d_445 (Conv2D)         (None, 7, 7, 256)         65792
#
#  batch_normalization_389 (Ba  (None, 7, 7, 256)        1024
#  tchNormalization)
#
#  activation_402 (Activation)  (None, 7, 7, 256)        0
#
#  conv2d_446 (Conv2D)         (None, 7, 7, 256)         590080
#
#  batch_normalization_390 (Ba  (None, 7, 7, 256)        1024
#  tchNormalization)
#
#  activation_403 (Activation)  (None, 7, 7, 256)        0
#
#  conv2d_447 (Conv2D)         (None, 7, 7, 1024)        263168
#
#  batch_normalization_391 (Ba  (None, 7, 7, 1024)       4096
#  tchNormalization)
#
#  activation_404 (Activation)  (None, 7, 7, 1024)       0
#
#  conv2d_448 (Conv2D)         (None, 7, 7, 256)         262400
#
#  batch_normalization_392 (Ba  (None, 7, 7, 256)        1024
#  tchNormalization)
#
#  activation_405 (Activation)  (None, 7, 7, 256)        0
#
#  conv2d_449 (Conv2D)         (None, 7, 7, 256)         590080
#
#  batch_normalization_393 (Ba  (None, 7, 7, 256)        1024
#  tchNormalization)
#
#  activation_406 (Activation)  (None, 7, 7, 256)        0
#
#  conv2d_450 (Conv2D)         (None, 7, 7, 1024)        263168
#
#  batch_normalization_394 (Ba  (None, 7, 7, 1024)       4096
#  tchNormalization)
#
#  activation_407 (Activation)  (None, 7, 7, 1024)       0
#
#  conv2d_451 (Conv2D)         (None, 7, 7, 256)         262400
#
#  batch_normalization_395 (Ba  (None, 7, 7, 256)        1024
#  tchNormalization)
#
#  activation_408 (Activation)  (None, 7, 7, 256)        0
#
#  conv2d_452 (Conv2D)         (None, 7, 7, 256)         590080
#
#  batch_normalization_396 (Ba  (None, 7, 7, 256)        1024
#  tchNormalization)
#
#  activation_409 (Activation)  (None, 7, 7, 256)        0
#
#  conv2d_453 (Conv2D)         (None, 7, 7, 1024)        263168
#
#  batch_normalization_397 (Ba  (None, 7, 7, 1024)       4096
#  tchNormalization)
#
#  activation_410 (Activation)  (None, 7, 7, 1024)       0
#
#  conv2d_454 (Conv2D)         (None, 7, 7, 256)         262400
#
#  batch_normalization_398 (Ba  (None, 7, 7, 256)        1024
#  tchNormalization)
#
#  activation_411 (Activation)  (None, 7, 7, 256)        0
#
#  conv2d_455 (Conv2D)         (None, 7, 7, 256)         590080
#
#  batch_normalization_399 (Ba  (None, 7, 7, 256)        1024
#  tchNormalization)
#
#  activation_412 (Activation)  (None, 7, 7, 256)        0
#
#  conv2d_456 (Conv2D)         (None, 7, 7, 1024)        263168
#
#  batch_normalization_400 (Ba  (None, 7, 7, 1024)       4096
#  tchNormalization)
#
#  activation_413 (Activation)  (None, 7, 7, 1024)       0
#
#  conv2d_457 (Conv2D)         (None, 7, 7, 256)         262400
#
#  batch_normalization_401 (Ba  (None, 7, 7, 256)        1024
#  tchNormalization)
#
#  activation_414 (Activation)  (None, 7, 7, 256)        0
#
#  conv2d_458 (Conv2D)         (None, 7, 7, 256)         590080
#
#  batch_normalization_402 (Ba  (None, 7, 7, 256)        1024
#  tchNormalization)
#
#  activation_415 (Activation)  (None, 7, 7, 256)        0
#
#  conv2d_459 (Conv2D)         (None, 7, 7, 1024)        263168
#
#  batch_normalization_403 (Ba  (None, 7, 7, 1024)       4096
#  tchNormalization)
#
#  activation_416 (Activation)  (None, 7, 7, 1024)       0
#
#  conv2d_460 (Conv2D)         (None, 7, 7, 256)         262400
#
#  batch_normalization_404 (Ba  (None, 7, 7, 256)        1024
#  tchNormalization)
#
#  activation_417 (Activation)  (None, 7, 7, 256)        0
#
#  conv2d_461 (Conv2D)         (None, 7, 7, 256)         590080
#
#  batch_normalization_405 (Ba  (None, 7, 7, 256)        1024
#  tchNormalization)
#
#  activation_418 (Activation)  (None, 7, 7, 256)        0
#
#  conv2d_462 (Conv2D)         (None, 7, 7, 1024)        263168
#
#  batch_normalization_406 (Ba  (None, 7, 7, 1024)       4096
#  tchNormalization)
#
#  activation_419 (Activation)  (None, 7, 7, 1024)       0
#
#  conv2d_463 (Conv2D)         (None, 7, 7, 64)          65600
#
#  batch_normalization_407 (Ba  (None, 7, 7, 64)         256
#  tchNormalization)
#
#  activation_420 (Activation)  (None, 7, 7, 64)         0
#
#  conv2d_464 (Conv2D)         (None, 7, 7, 64)          36928
#
#  batch_normalization_408 (Ba  (None, 7, 7, 64)         256
#  tchNormalization)
#
#  activation_421 (Activation)  (None, 7, 7, 64)         0
#
#  conv2d_465 (Conv2D)         (None, 7, 7, 256)         16640
#
#  batch_normalization_409 (Ba  (None, 7, 7, 256)        1024
#  tchNormalization)
#
#  activation_422 (Activation)  (None, 7, 7, 256)        0
#
#  conv2d_466 (Conv2D)         (None, 7, 7, 64)          16448
#
#  batch_normalization_410 (Ba  (None, 7, 7, 64)         256
#  tchNormalization)
#
#  activation_423 (Activation)  (None, 7, 7, 64)         0
#
#  conv2d_467 (Conv2D)         (None, 7, 7, 64)          36928
#
#  batch_normalization_411 (Ba  (None, 7, 7, 64)         256
#  tchNormalization)
#
#  activation_424 (Activation)  (None, 7, 7, 64)         0
#
#  conv2d_468 (Conv2D)         (None, 7, 7, 256)         16640
#
#  batch_normalization_412 (Ba  (None, 7, 7, 256)        1024
#  tchNormalization)
#
#  activation_425 (Activation)  (None, 7, 7, 256)        0
#
#  conv2d_469 (Conv2D)         (None, 7, 7, 64)          16448
#
#  batch_normalization_413 (Ba  (None, 7, 7, 64)         256
#  tchNormalization)
#
#  activation_426 (Activation)  (None, 7, 7, 64)         0
#
#  conv2d_470 (Conv2D)         (None, 7, 7, 64)          36928
#
#  batch_normalization_414 (Ba  (None, 7, 7, 64)         256
#  tchNormalization)
#
#  activation_427 (Activation)  (None, 7, 7, 64)         0
#
#  conv2d_471 (Conv2D)         (None, 7, 7, 256)         16640
#
#  batch_normalization_415 (Ba  (None, 7, 7, 256)        1024
#  tchNormalization)
#
#  activation_428 (Activation)  (None, 7, 7, 256)        0
#
#  conv2d_472 (Conv2D)         (None, 4, 4, 512)         131584
#
#  batch_normalization_416 (Ba  (None, 4, 4, 512)        2048
#  tchNormalization)
#
#  activation_429 (Activation)  (None, 4, 4, 512)        0
#
#  conv2d_473 (Conv2D)         (None, 4, 4, 512)         2359808
#
#  batch_normalization_417 (Ba  (None, 4, 4, 512)        2048
#  tchNormalization)
#
#  activation_430 (Activation)  (None, 4, 4, 512)        0
#
#  conv2d_474 (Conv2D)         (None, 4, 4, 2048)        1050624
#
#  batch_normalization_418 (Ba  (None, 4, 4, 2048)       8192
#  tchNormalization)
#
#  activation_431 (Activation)  (None, 4, 4, 2048)       0
#
#  conv2d_475 (Conv2D)         (None, 4, 4, 512)         1049088
#
#  batch_normalization_419 (Ba  (None, 4, 4, 512)        2048
#  tchNormalization)
#
#  activation_432 (Activation)  (None, 4, 4, 512)        0
#
#  conv2d_476 (Conv2D)         (None, 4, 4, 512)         2359808
#
#  batch_normalization_420 (Ba  (None, 4, 4, 512)        2048
#  tchNormalization)
#
#  activation_433 (Activation)  (None, 4, 4, 512)        0
#
#  conv2d_477 (Conv2D)         (None, 4, 4, 2048)        1050624
#
#  batch_normalization_421 (Ba  (None, 4, 4, 2048)       8192
#  tchNormalization)
#
#  activation_434 (Activation)  (None, 4, 4, 2048)       0
#
#  conv2d_478 (Conv2D)         (None, 4, 4, 512)         1049088
#
#  batch_normalization_422 (Ba  (None, 4, 4, 512)        2048
#  tchNormalization)
#
#  activation_435 (Activation)  (None, 4, 4, 512)        0
#
#  conv2d_479 (Conv2D)         (None, 4, 4, 512)         2359808
#
#  batch_normalization_423 (Ba  (None, 4, 4, 512)        2048
#  tchNormalization)
#
#  activation_436 (Activation)  (None, 4, 4, 512)        0
#
#  conv2d_480 (Conv2D)         (None, 4, 4, 2048)        1050624
#
#  batch_normalization_424 (Ba  (None, 4, 4, 2048)       8192
#  tchNormalization)
#
#  activation_437 (Activation)  (None, 4, 4, 2048)       0
#
#  average_pooling2d_6 (Averag  (None, 2, 2, 2048)       0
#  ePooling2D)
#
#  flatten_6 (Flatten)         (None, 8192)              0
#
#  dense_6 (Dense)             (None, 1000)              8193000
#
# =================================================================
# Total params: 29,028,712
# Trainable params: 28,978,664
# Non-trainable params: 50,048
# _________________________________________________________________

# %%
# ResNet-34 plain 모델을 컴파일하고 학습 진행
resnet_34_plain.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

history_34_plain = resnet_34_plain.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:75%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[75%:90%]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/15
# c:\Users\ZAKAR\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 272/272 [==============================] - 29s 85ms/step - loss: 0.9773 - accuracy: 0.4959 - val_loss: 0.9366 - val_accuracy: 0.4962
# Epoch 2/15
# 272/272 [==============================] - 22s 83ms/step - loss: 0.7259 - accuracy: 0.5035 - val_loss: 0.7232 - val_accuracy: 0.5026
# Epoch 3/15
# 272/272 [==============================] - 23s 83ms/step - loss: 0.7223 - accuracy: 0.4982 - val_loss: 1.6764 - val_accuracy: 0.5130
# Epoch 4/15
# 272/272 [==============================] - 22s 83ms/step - loss: 0.7158 - accuracy: 0.5082 - val_loss: 0.8116 - val_accuracy: 0.5020
# Epoch 5/15
# 272/272 [==============================] - 23s 84ms/step - loss: 0.7162 - accuracy: 0.5020 - val_loss: 1.0003 - val_accuracy: 0.5029
# Epoch 6/15
# 272/272 [==============================] - 23s 85ms/step - loss: 0.7130 - accuracy: 0.5124 - val_loss: 0.7005 - val_accuracy: 0.5043
# Epoch 7/15
# 272/272 [==============================] - 23s 83ms/step - loss: 0.7088 - accuracy: 0.5136 - val_loss: 0.7472 - val_accuracy: 0.5104
# Epoch 8/15
# 272/272 [==============================] - 23s 83ms/step - loss: 0.7060 - accuracy: 0.5252 - val_loss: 0.7295 - val_accuracy: 0.5058
# Epoch 9/15
# 272/272 [==============================] - 23s 83ms/step - loss: 0.7117 - accuracy: 0.5064 - val_loss: 0.7109 - val_accuracy: 0.4980
# Epoch 10/15
# 272/272 [==============================] - 22s 83ms/step - loss: 0.7062 - accuracy: 0.5247 - val_loss: 0.7408 - val_accuracy: 0.5006
# Epoch 11/15
# 272/272 [==============================] - 23s 83ms/step - loss: 0.7035 - accuracy: 0.5242 - val_loss: 0.7263 - val_accuracy: 0.4997
# Epoch 12/15
# 272/272 [==============================] - 23s 83ms/step - loss: 0.7047 - accuracy: 0.5234 - val_loss: 0.7382 - val_accuracy: 0.4925
# Epoch 13/15
# 272/272 [==============================] - 22s 83ms/step - loss: 0.7037 - accuracy: 0.5227 - val_loss: 0.7138 - val_accuracy: 0.5243
# Epoch 14/15
# 272/272 [==============================] - 22s 82ms/step - loss: 0.7061 - accuracy: 0.5146 - val_loss: 0.7409 - val_accuracy: 0.4916
# Epoch 15/15
# 272/272 [==============================] - 23s 83ms/step - loss: 0.6983 - accuracy: 0.5275 - val_loss: 0.7381 - val_accuracy: 0.5310

# %%
# ResNet-50 plain 모델을 컴파일하고 학습 진행
resnet_50_plain.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01, clipnorm=1.),
    metrics=['accuracy'],
)

history_50_plain = resnet_50_plain.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:75%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[75%:90%]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/15
# 272/272 [==============================] - 40s 115ms/step - loss: 1.0812 - accuracy: 0.4972 - val_loss: 0.8372 - val_accuracy: 0.4962
# Epoch 2/15
# 272/272 [==============================] - 31s 112ms/step - loss: 0.7336 - accuracy: 0.5074 - val_loss: 0.7096 - val_accuracy: 0.4977
# Epoch 3/15
# 272/272 [==============================] - 31s 112ms/step - loss: 0.7327 - accuracy: 0.5077 - val_loss: 0.9337 - val_accuracy: 0.5095
# Epoch 4/15
# 272/272 [==============================] - 31s 112ms/step - loss: 0.7288 - accuracy: 0.5076 - val_loss: 2.1772 - val_accuracy: 0.4997
# Epoch 5/15
# 272/272 [==============================] - 31s 112ms/step - loss: 0.7323 - accuracy: 0.5039 - val_loss: 1.1987 - val_accuracy: 0.5038
# Epoch 6/15
# 272/272 [==============================] - 30s 112ms/step - loss: 0.7290 - accuracy: 0.5006 - val_loss: 0.9778 - val_accuracy: 0.4890
# Epoch 7/15
# 272/272 [==============================] - 31s 112ms/step - loss: 0.7284 - accuracy: 0.4971 - val_loss: 1.0508 - val_accuracy: 0.4942
# Epoch 8/15
# 272/272 [==============================] - 30s 112ms/step - loss: 0.7272 - accuracy: 0.5043 - val_loss: 1.5303 - val_accuracy: 0.4968
# Epoch 9/15
# 272/272 [==============================] - 30s 112ms/step - loss: 0.7282 - accuracy: 0.5006 - val_loss: 0.8537 - val_accuracy: 0.4988
# Epoch 10/15
# 272/272 [==============================] - 30s 112ms/step - loss: 0.7245 - accuracy: 0.5051 - val_loss: 0.7054 - val_accuracy: 0.5191
# Epoch 11/15
# 272/272 [==============================] - 30s 112ms/step - loss: 0.7253 - accuracy: 0.5026 - val_loss: 0.7171 - val_accuracy: 0.4884
# Epoch 12/15
# 272/272 [==============================] - 30s 112ms/step - loss: 0.7272 - accuracy: 0.5010 - val_loss: 0.8874 - val_accuracy: 0.4896
# Epoch 13/15
# 272/272 [==============================] - 30s 112ms/step - loss: 0.7223 - accuracy: 0.5029 - val_loss: 1.0840 - val_accuracy: 0.4905
# Epoch 14/15
# 272/272 [==============================] - 30s 111ms/step - loss: 0.7244 - accuracy: 0.4982 - val_loss: 1.0916 - val_accuracy: 0.5020
# Epoch 15/15
# 272/272 [==============================] - 30s 112ms/step - loss: 0.7252 - accuracy: 0.4972 - val_loss: 0.7035 - val_accuracy: 0.4957

# %%
# 모델 학습 결과를 출력 (validation accuracy, validation loss)
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(history_34.history['val_accuracy'])
plt.plot(history_50.history['val_accuracy'])
plt.plot(history_34_plain.history['val_accuracy'])
plt.plot(history_50_plain.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['val_34', 'val_50', 'val_34_plain', 'val_50_plain'], loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history_34.history['val_loss'])
plt.plot(history_50.history['val_loss'])
plt.plot(history_34_plain.history['val_loss'])
plt.plot(history_50_plain.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['val_34', 'val_50', 'val_34_plain', 'val_50_plain'], loc='upper left')

plt.show()
